# %%
import numpy as np
import pandas as pd
from pathlib import Path
from collections import Counter
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, MinMaxScaler, LabelEncoder
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
# Load the data. 
# Used zip file bcse csv file was too big to upload to github.
#df = pd.read_csv('../Resources/2017.csv')
df = pd.read_csv('../Resources/ICAO_airports.csv')
df.head(3).append(df.tail(3))
# Out:
#           id    ident            type                         name  \
# 0       6523      00A        heliport            Total Rf Heliport
# 1       6524     00AK   small_airport                 Lowell Field
# 2       6525     00AL   small_airport                 Epps Airpark
# 43927  27244     ZYYJ  medium_airport  Yanji Chaoyangchuan Airport
# 43928  32753     ZYYY  medium_airport      Shenyang Dongta Airport
# 43929  46378  ZZ-0001        heliport              Sealand Helipad
#
#        latitude_deg  longitude_deg  elevation_ft continent iso_country  \
# 0         40.070801     -74.933601          11.0       NaN          US
# 1         59.949200    -151.695999         450.0       NaN          US
# 2         34.864799     -86.770302         820.0       NaN          US
# 43927     42.882801     129.451004         624.0        AS          CN
# 43928     41.784401     123.496002           NaN        AS          CN
# ...

# %%
df = df.loc[df['iso_country'] == 'US']
df = df[df.type.isin(['small_airport', 'medium_airport','large_airport'])]
df = df[['name', 'latitude_deg','longitude_deg','iso_region','local_code','type']].reset_index()


df.head(3).append(df.tail(3))
# Out:
#        index                     name  latitude_deg  longitude_deg iso_region  \
# 0          1             Lowell Field     59.949200    -151.695999      US-AK
# 1          2             Epps Airpark     34.864799     -86.770302      US-AL
# 2          4           Cordes Airport     34.305599    -112.165001      US-AZ
# 14715  43661  Copper Center 2 Airport     61.941200    -145.294006      US-AK
# 14716  43662          Cibecue Airport     34.003300    -110.444000      US-AZ
# 14717  43844             Nyac Airport     60.980701    -159.994003      US-AK
#
#       local_code           type
# 0           00AK  small_airport
# 1           00AL  small_airport
# 2           00AZ  small_airport
# 14715        Z93  small_airport
# 14716        Z95  small_airport
# 14717        ZNC  small_airport

# %%
df[['country', 'state']] = df['iso_region'].str.split('-', 1, expand=True)
df
# Out:
#        index                     name  latitude_deg  longitude_deg iso_region  \
# 0          1             Lowell Field     59.949200    -151.695999      US-AK
# 1          2             Epps Airpark     34.864799     -86.770302      US-AL
# 2          4           Cordes Airport     34.305599    -112.165001      US-AZ
# 3          5  Goldstone /Gts/ Airport     35.350498    -116.888000      US-CA
# 4          6               Cass Field     40.622200    -104.344002      US-CO
# ...      ...                      ...           ...            ...        ...
# 14713  43659      Birch Creek Airport     66.274002    -145.824005      US-AK
# 14714  43660   Harsens Island Airport     42.589699     -82.576401      US-MI
# 14715  43661  Copper Center 2 Airport     61.941200    -145.294006      US-AK
# 14716  43662          Cibecue Airport     34.003300    -110.444000      US-AZ
# 14717  43844             Nyac Airport     60.980701    -159.994003      US-AK
#
# ...

# %%
df.state.unique()
# Out:
# array(['AK', 'AL', 'AZ', 'CA', 'CO', 'FL', 'GA', 'ID', 'IL', 'KS', 'KY',
#        'LA', 'MD', 'MN', 'MO', 'MT', 'NJ', 'NC', 'NY', 'OH', 'PA', 'OR',
#        'SC', 'TN', 'TX', 'VA', 'WA', 'WI', 'WV', 'MI', 'IA', 'IN', 'NE',
#        'NH', 'NM', 'NV', 'OK', 'UT', 'WY', 'AR', 'MS', 'ME', 'MA', 'ND',
#        'VT', 'RI', 'DE', 'SD', 'CT', 'HI', 'DC', 'U-A'], dtype=object)
